# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1.
#     - a) $\pi_{egyetem} (h)$ \ $\pi_{egyetem} (á)$
#     - b) $\underbrace{\pi_{nev} (h)}_{\text{összes hallgató}}$ \ $\underbrace{\pi_{nev}(h \bowtie á)}_{\text{államilag támogatott hallgatók}}$
#     - c)
#         - $h_1 = h_2 = h$ - két különböző másolat h-ból
#         - $'c' = \pi_{h1.szak}(\sigma_{h1.szak = h2.szak \land h1.egyetem \neq h2.egyetem}(h1 \bowtie h2))$
#     - d) $\pi_{szak}(h) \ 'c'$
#     - e) legkisebb elemmegtalálása
#         - hint: adott számok(Szám) relációs séma, ebből csinálunk két másolatot sz1 = sz2 = sz. \
#         adott reláció:
#
#         \begin{aligned}
#         \begin{array}{c }
#         sz1\\
#         5 \\
#         1 \\
#         2
#         \end{array}
#         \end{aligned}
#         - képezzük $\sigma_{sz1.szam < sz2.szam} (sz1 \bowtie sz2)$
#         \begin{aligned}
#         \begin{array}{c | c}
#         sz1 &  sz2\\
#         1 & 5 \\
#         2 & 5 \\
#         1 & 2
#         \end{array}
#         \end{aligned}
#         - az sz2 oszlopból csak az 1-es hiányzik, nála nincs kisebb, tehát a legkisebb elem megtalálásához ezt az oszlopot kell kivonni (különbség képzés) az eredeti szám halmazból (reláció)
#         - $sz$ \ $(\pi_{sz2.szam}[\sigma_{sz1.szam < sz2.szam} (sz1 \bowtie sz2)])$
#
#         - e megoldása: á1 = á2 = á
#         - $\big[ \pi_{á.alapév}(á) \setminus (\pi_{á2.alapév} \sigma_{á1.alapév < á2.alapév}( á1 \bowtie á2))  \big] \bowtie á$
#         - vége: $\bowtie á$ ,mert kaptunk egy dátumot, még vissza kell illesztenünk egy egyetemmel

# %% [markdown]
# 2. sorkalkulus
# - a)
#     - off: $\{ x^{(1)} | (\exist á^{(2)}) Á^{(2)}(a^{(2)}) \land x^{(1)}[1] = á^{(2)}[1] \}$
#
#
# - $\{ x^{(1)} | (\exist h^{(4)}) H^{(4)}(h^{(4)}) \land x^{(1)}[1] = h^{(4)}[2]  \land \neg (\exist á^{(2)}) Á^{(2)}(á^{(2)}) \land x^{(1)}[1] = á^{(2)}[1] \}$
# - legyen benne a h relációban úgy mint egy egyetem neve, de ne legyen benne az á relációban úgy mint egy egyetem neve
#
# - b) $\{ x^{(1)} | (\exist h^{(4)}) H(h) \land x[1] = h[1]  \land \neg (\exist á^{(2)}) Á(á) \land h[2] = á[1] \}$

# %% [markdown]
# Oszlopkalkulus
# - b)  $\{ x | (\exist d,e,f,g) H(d,e,f,g) \land d = x  \land \neg (\exist t,v) Á(t,v) \land e = t \}$
